# %%
import pandas as pd

# %%
df = pd.read_csv('food.csv')

# %%
df.head()
# Out:
#   Category                     Description  Nutrient Data Bank Number
# 0     Milk                     Milk, human                   11000000  \
# 1     Milk                       Milk, NFS                   11100000
# 2     Milk                     Milk, whole                   11111000
# 3     Milk         Milk, low sodium, whole                   11111100
# 4     Milk  Milk, calcium fortified, whole                   11111150
#
#    Data.Alpha Carotene  Data.Beta Carotene  Data.Beta Cryptoxanthin
# 0                    0                   7                        0  \
# 1                    0                   4                        0
# 2                    0                   7                        0
# 3                    0                   7                        0
# 4                    0                   7                        0
#
#    Data.Carbohydrate  Data.Cholesterol  Data.Choline  Data.Fiber  ...
# ...

# %%
print(df.iloc[4])
# Out:
# Category                                                    Milk
# Description                       Milk, calcium fortified, whole
# Nutrient Data Bank Number                               11111150
# Data.Alpha Carotene                                            0
# Data.Beta Carotene                                             7
# Data.Beta Cryptoxanthin                                        0
# Data.Carbohydrate                                           4.67
# Data.Cholesterol                                              12
# Data.Choline                                                17.8
# Data.Fiber                                                   0.0
# Data.Lutein and Zeaxanthin                                     0
# Data.Lycopene                                                  0
# Data.Niacin                                                0.105
# Data.Protein                                                3.28
# ...

# %%
print(df.iloc[1])
# Out:
# Category                               Milk
# Description                       Milk, NFS
# Nutrient Data Bank Number          11100000
# Data.Alpha Carotene                       0
# Data.Beta Carotene                        4
# Data.Beta Cryptoxanthin                   0
# Data.Carbohydrate                      4.87
# Data.Cholesterol                          8
# Data.Choline                           17.9
# Data.Fiber                              0.0
# Data.Lutein and Zeaxanthin                0
# Data.Lycopene                             0
# Data.Niacin                            0.11
# Data.Protein                           3.34
# Data.Retinol                             58
# Data.Riboflavin                       0.137
# Data.Selenium                           1.9
# Data.Sugar Total                       4.89
# Data.Thiamin                          0.057
# Data.Water                            89.04
# Data.Fat.Monosaturated Fat            0.426
# ...

# %%
WithoutCholine = df.drop('Data.Choline', axis=1)

# %%
print(df)
# Out:
#                                       Category
# 0                                         Milk  \
# 1                                         Milk
# 2                                         Milk
# 3                                         Milk
# 4                                         Milk
# ...                                        ...
# 7078          Tomatoes as ingredient in omelet
# 7079  Other vegetables as ingredient in omelet
# 7080         Vegetables as ingredient in curry
# 7081         Sauce as ingredient in hamburgers
# 7082      Industrial oil as ingredient in food
#
#                                    Description  Nutrient Data Bank Number
# 0                                  Milk, human                   11000000  \
# 1                                    Milk, NFS                   11100000
# 2                                  Milk, whole                   11111000
# 3                      Milk, low sodium, whole                   11111100
# ...

# %%
df.isnull()
# Out:
#       Category  Description  Nutrient Data Bank Number  Data.Alpha Carotene
# 0        False        False                      False                False  \
# 1        False        False                      False                False
# 2        False        False                      False                False
# 3        False        False                      False                False
# 4        False        False                      False                False
# ...        ...          ...                        ...                  ...
# 7078     False        False                      False                False
# 7079     False        False                      False                False
# 7080     False        False                      False                False
# 7081     False        False                      False                False
# 7082     False        False                      False                False
#
# ...

# %%
print(df['Data.Cholesterol'])
# Out:
# 0       14
# 1        8
# 2       12
# 3       14
# 4       12
#         ..
# 7078     0
# 7079     0
# 7080     0
# 7081    13
# 7082     0
# Name: Data.Cholesterol, Length: 7083, dtype: int64

# %%
print(df.sort_values(by='Data.Carbohydrate'))
# Out:
#               Category                                        Description
# 688               Beef  Beef, pot roast, braised or boiled, NS as to f...  \
# 1104            Turkey             Turkey, drumstick, roasted, skin eaten
# 1105            Turkey              Turkey, drumstick, smoked, skin eaten
# 692               Beef        Beef, stew meat, cooked, lean and fat eaten
# 691               Beef        Beef, stew meat, cooked, NS as to fat eaten
# ...                ...                                                ...
# 6422             Sugar                                         Sugar, NFS
# 6423             Sugar                   Sugar, white, granulated or lump
# 6424             Sugar             Sugar, white, confectioner's, powdered
# 6431  Sugar substitute               Sugar substitute, monk fruit, powder
# 6429  Sugar substitute                   Sugar substitute, stevia, powder
#
#       Nutrient Data Bank Number  Data.Alpha Carotene  Data.Beta Carotene
# ...

# %%
df['Category'].unique()
# Out:
# array(['Milk', 'Buttermilk', 'Kefir', ...,
#        'Vegetables as ingredient in curry',
#        'Sauce as ingredient in hamburgers',
#        'Industrial oil as ingredient in food'], dtype=object)

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(df['Category'], df['Data.Carbohydrate'], color='Skyblue')
plt.xlabel('Category')
plt.ylabel('Data.Carbohydrate')
plt.title('Bar chart from CSV')
plt.show()

# %%
plt.scatter(df['Category'], df['Data.Cholesterol'], color='Blue', label='Data points')
plt.title('Scatter plot from csv data')
plt.xlabel('Category')
plt.ylabel('Data.Cholesterol')
plt.legend()
plt.show()
